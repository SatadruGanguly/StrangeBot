# %%
import pandas as pd
import nltk
import re

# %%
data = pd.read_csv('Symptom-severity.csv')

# %%
data.head()
# Out:
#                 Symptom  weight
# 0               itching       1
# 1             skin_rash       3
# 2  nodal_skin_eruptions       4
# 3   continuous_sneezing       4
# 4             shivering       5

# %%
data.tail()
# Out:
#                   Symptom  weight
# 128    inflammatory_nails       2
# 129               blister       4
# 130  red_sore_around_nose       2
# 131     yellow_crust_ooze       3
# 132             prognosis       5

# %%
symptom_list = list(data['Symptom'][:132])
symptom_list
# Out:
# ['itching',
#  'skin_rash',
#  'nodal_skin_eruptions',
#  'continuous_sneezing',
#  'shivering',
#  'chills',
#  'joint_pain',
#  'stomach_pain',
#  'acidity',
#  'ulcers_on_tongue',
#  'muscle_wasting',
#  'vomiting',
#  'burning_micturition',
#  'spotting_urination',
#  'fatigue',
#  'weight_gain',
#  'anxiety',
#  'cold_hands_and_feets',
#  'mood_swings',
#  'weight_loss',
#  'restlessness',
#  'lethargy',
#  'patches_in_throat',
#  'irregular_sugar_level',
#  'cough',
#  'high_fever',
#  'sunken_eyes',
#  'breathlessness',
#  'sweating',
#  'dehydration',
#  'indigestion',
#  'headache',
#  'yellowish_skin',
#  'dark_urine',
#  'nausea',
#  'loss_of_appetite',
#  'pain_behind_the_eyes',
#  'back_pain',
#  'constipation',
#  'abdominal_pain',
#  'diarrhoea',
#  'mild_fever',
#  'yellow_urine',
#  'yellowing_of_eyes',
#  'acute_liver_failure',
#  'fluid_overload',
#  'swelling_of_stomach',
#  'swelled_lymph_nodes',
#  'malaise',
#  'blurred_and_distorted_vision',
#  'phlegm',
#  'throat_irritation',
#  'redness_of_eyes',
#  'sinus_pressure',
#  'runny_nose',
#  'congestion',
#  'chest_pain',
#  'weakness_in_limbs',
#  'fast_heart_rate',
#  'pain_during_bowel_movements',
#  'pain_in_anal_region',
#  'bloody_stool',
#  'irritation_in_anus',
#  'neck_pain',
#  'dizziness',
#  'cramps',
#  'bruising',
#  'obesity',
#  'swollen_legs',
#  'swollen_blood_vessels',
#  'puffy_face_and_eyes',
#  'enlarged_thyroid',
#  'brittle_nails',
#  'swollen_extremeties',
#  'excessive_hunger',
#  'extra_marital_contacts',
#  'drying_and_tingling_lips',
#  'slurred_speech',
#  'knee_pain',
#  'hip_joint_pain',
#  'muscle_weakness',
#  'stiff_neck',
#  'swelling_joints',
#  'movement_stiffness',
#  'spinning_movements',
#  'loss_of_balance',
#  'unsteadiness',
#  'weakness_of_one_body_side',
#  'loss_of_smell',
#  'bladder_discomfort',
#  'foul_smell_ofurine',
#  'continuous_feel_of_urine',
#  'passage_of_gases',
#  'internal_itching',
#  'toxic_look_(typhos)',
#  'depression',
#  'irritability',
#  'muscle_pain',
#  'altered_sensorium',
#  'red_spots_over_body',
#  'belly_pain',
#  'abnormal_menstruation',
#  'dischromic_patches',
#  'watering_from_eyes',
#  'increased_appetite',
#  'polyuria',
#  'family_history',
#  'mucoid_sputum',
#  'rusty_sputum',
#  'lack_of_concentration',
#  'visual_disturbances',
#  'receiving_blood_transfusion',
#  'receiving_unsterile_injections',
#  'coma',
#  'stomach_bleeding',
#  'distention_of_abdomen',
#  'history_of_alcohol_consumption',
#  'fluid_overload',
#  'blood_in_sputum',
#  'prominent_veins_on_calf',
#  'palpitations',
#  'painful_walking',
#  'pus_filled_pimples',
#  'blackheads',
#  'scurring',
#  'skin_peeling',
#  'silver_like_dusting',
#  'small_dents_in_nails',
#  'inflammatory_nails',
#  'blister',
#  'red_sore_around_nose',
#  'yellow_crust_ooze']

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
stemmed_symptom_list = []
spaced_symptom_list = []
snow_stemmer = nltk.stem.snowball.SnowballStemmer(language='english')

# %%
for symptom in symptom_list:
    words = symptom.split('_')
    new_word = ''
    for w in words:
        nw = snow_stemmer.stem(w)
        new_word = new_word + nw + ' '
    spaced_word = re.sub('_', ' ', symptom)
    stemmed_symptom_list.append(new_word.strip())
    spaced_symptom_list.append(spaced_word.strip())

# %%
stemmed_symptom_list
# Out:
# ['itch',
#  'skin rash',
#  'nodal skin erupt',
#  'continu sneez',
#  'shiver',
#  'chill',
#  'joint pain',
#  'stomach pain',
#  'acid',
#  'ulcer on tongu',
#  'muscl wast',
#  'vomit',
#  'burn micturit',
#  'spot urin',
#  'fatigu',
#  'weight gain',
#  'anxieti',
#  'cold hand and feet',
#  'mood swing',
#  'weight loss',
#  'restless',
#  'lethargi',
#  'patch in throat',
#  'irregular sugar level',
#  'cough',
#  'high fever',
#  'sunken eye',
#  'breathless',
#  'sweat',
#  'dehydr',
#  'indigest',
#  'headach',
#  'yellowish skin',
#  'dark urin',
#  'nausea',
#  'loss of appetit',
#  'pain behind the eye',
#  'back pain',
#  'constip',
#  'abdomin pain',
#  'diarrhoea',
#  'mild fever',
#  'yellow urin',
#  'yellow of eye',
#  'acut liver failur',
#  'fluid overload',
#  'swell of stomach',
#  'swell lymph node',
#  'malais',
#  'blur and distort vision',
#  'phlegm',
#  'throat irrit',
#  'red of eye',
#  'sinus pressur',
#  'runni nose',
#  'congest',
#  'chest pain',
#  'weak in limb',
#  'fast heart rate',
#  'pain dure bowel movement',
#  'pain in anal region',
#  'bloodi stool',
#  'irrit in anus',
#  'neck pain',
#  'dizzi',
#  'cramp',
#  'bruis',
#  'obes',
#  'swollen leg',
#  'swollen blood vessel',
#  'puffi face and eye',
#  'enlarg thyroid',
#  'brittl nail',
#  'swollen extremeti',
#  'excess hunger',
#  'extra marit contact',
#  'dri and tingl lip',
#  'slur speech',
#  'knee pain',
#  'hip joint pain',
#  'muscl weak',
#  'stiff neck',
#  'swell joint',
#  'movement stiff',
#  'spin movement',
#  'loss of balanc',
#  'unsteadi',
#  'weak of one bodi side',
#  'loss of smell',
#  'bladder discomfort',
#  'foul smell ofurin',
#  'continu feel of urin',
#  'passag of gase',
#  'intern itch',
#  'toxic look (typhos)',
#  'depress',
#  'irrit',
#  'muscl pain',
#  'alter sensorium',
#  'red spot over bodi',
#  'belli pain',
#  'abnorm menstruat',
#  'dischrom patch',
#  'water from eye',
#  'increas appetit',
#  'polyuria',
#  'famili histori',
#  'mucoid sputum',
#  'rusti sputum',
#  'lack of concentr',
#  'visual disturb',
#  'receiv blood transfus',
#  'receiv unsteril inject',
#  'coma',
#  'stomach bleed',
#  'distent of abdomen',
#  'histori of alcohol consumpt',
#  'fluid overload',
#  'blood in sputum',
#  'promin vein on calf',
#  'palpit',
#  'pain walk',
#  'pus fill pimpl',
#  'blackhead',
#  'scur',
#  'skin peel',
#  'silver like dust',
#  'small dent in nail',
#  'inflammatori nail',
#  'blister',
#  'red sore around nose',
#  'yellow crust ooz']

# %%
snow_stemmer.stem('shivering')
# Out:
# 'shiver'

# %%
spaced_symptom_list
# Out:
# ['itching',
#  'skin rash',
#  'nodal skin eruptions',
#  'continuous sneezing',
#  'shivering',
#  'chills',
#  'joint pain',
#  'stomach pain',
#  'acidity',
#  'ulcers on tongue',
#  'muscle wasting',
#  'vomiting',
#  'burning micturition',
#  'spotting urination',
#  'fatigue',
#  'weight gain',
#  'anxiety',
#  'cold hands and feets',
#  'mood swings',
#  'weight loss',
#  'restlessness',
#  'lethargy',
#  'patches in throat',
#  'irregular sugar level',
#  'cough',
#  'high fever',
#  'sunken eyes',
#  'breathlessness',
#  'sweating',
#  'dehydration',
#  'indigestion',
#  'headache',
#  'yellowish skin',
#  'dark urine',
#  'nausea',
#  'loss of appetite',
#  'pain behind the eyes',
#  'back pain',
#  'constipation',
#  'abdominal pain',
#  'diarrhoea',
#  'mild fever',
#  'yellow urine',
#  'yellowing of eyes',
#  'acute liver failure',
#  'fluid overload',
#  'swelling of stomach',
#  'swelled lymph nodes',
#  'malaise',
#  'blurred and distorted vision',
#  'phlegm',
#  'throat irritation',
#  'redness of eyes',
#  'sinus pressure',
#  'runny nose',
#  'congestion',
#  'chest pain',
#  'weakness in limbs',
#  'fast heart rate',
#  'pain during bowel movements',
#  'pain in anal region',
#  'bloody stool',
#  'irritation in anus',
#  'neck pain',
#  'dizziness',
#  'cramps',
#  'bruising',
#  'obesity',
#  'swollen legs',
#  'swollen blood vessels',
#  'puffy face and eyes',
#  'enlarged thyroid',
#  'brittle nails',
#  'swollen extremeties',
#  'excessive hunger',
#  'extra marital contacts',
#  'drying and tingling lips',
#  'slurred speech',
#  'knee pain',
#  'hip joint pain',
#  'muscle weakness',
#  'stiff neck',
#  'swelling joints',
#  'movement stiffness',
#  'spinning movements',
#  'loss of balance',
#  'unsteadiness',
#  'weakness of one body side',
#  'loss of smell',
#  'bladder discomfort',
#  'foul smell ofurine',
#  'continuous feel of urine',
#  'passage of gases',
#  'internal itching',
#  'toxic look (typhos)',
#  'depression',
#  'irritability',
#  'muscle pain',
#  'altered sensorium',
#  'red spots over body',
#  'belly pain',
#  'abnormal menstruation',
#  'dischromic patches',
#  'watering from eyes',
#  'increased appetite',
#  'polyuria',
#  'family history',
#  'mucoid sputum',
#  'rusty sputum',
#  'lack of concentration',
#  'visual disturbances',
#  'receiving blood transfusion',
#  'receiving unsterile injections',
#  'coma',
#  'stomach bleeding',
#  'distention of abdomen',
#  'history of alcohol consumption',
#  'fluid overload',
#  'blood in sputum',
#  'prominent veins on calf',
#  'palpitations',
#  'painful walking',
#  'pus filled pimples',
#  'blackheads',
#  'scurring',
#  'skin peeling',
#  'silver like dusting',
#  'small dents in nails',
#  'inflammatory nails',
#  'blister',
#  'red sore around nose',
#  'yellow crust ooze']

# %%
new_dict = {stemmed_symptom_list, spaced_symptom_list, symptom_list)
new_dict
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\gsata\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1674                 blocks = [
# -> 1675                     make_block(
#    1676                         values=blocks[0], placement=slice(0, len(axes[0])), ndim=2
#
# c:\users\gsata\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2750
# -> 2751     return klass(values, ndim=ndim, placement=placement)
#    2752
#
# c:\users\gsata\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     141         if self._validate_ndim and self.ndim and len(self.mgr_locs) != len(self.values):
# --> 142             raise ValueError(
#     143                 f"Wrong number of items passed {len(self.values)}, "
#
# ValueError: Wrong number of items passed 1, placement implies 132
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-f5b6521f6259> in <module>
# ----> 1 new_dict = pd.DataFrame(stemmed_symptom_list, spaced_symptom_list, symptom_list)
#       2 new_dict
#
# c:\users\gsata\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     582                     mgr = arrays_to_mgr(arrays, columns, index, columns, dtype=dtype)
#     583                 else:
# --> 584                     mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     585             else:
#     586                 mgr = init_dict({}, index, columns, dtype=dtype)
#
# c:\users\gsata\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     236         block_values = [values]
#     237
# --> 238     return create_block_manager_from_blocks(block_values, [columns, index])
#     239
#     240
#
# c:\users\gsata\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1685         blocks = [getattr(b, "values", b) for b in blocks]
#    1686         tot_items = sum(b.shape[0] for b in blocks)
# -> 1687         raise construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    1688
#    1689
#
# ValueError: Shape of passed values is (132, 1), indices imply (132, 132)

# %%
print(len(stemmed_symptom_list))
print(len(spaced_symptom_list))
print(len(symptom_list))
# Out:
# 132
# 132
# 132

# %%
new_dict.to_csv('symptom-list.csv')
